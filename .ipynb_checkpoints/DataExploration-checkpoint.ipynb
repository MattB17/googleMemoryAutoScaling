# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/mattb/Desktop/Courses/MemoryAutoScaling/data/task_usage_df1298.csv")

# %%
pd.options.display.max_columns = None

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#          start_time       end_time  collection_id  instance_index  \
# 0     1000200000000  1000500000000           1298               0
# 1     1000500000000  1000800000000           1298               0
# 2     1000800000000  1001100000000           1298               0
# 3     1001100000000  1001400000000           1298               0
# 4     1001400000000  1001700000000           1298               0
# ...             ...            ...            ...             ...
# 9038    99900000000   100200000000           1298               0
# 9039   999000000000   999300000000           1298               0
# 9040   999300000000   999600000000           1298               0
# 9041   999600000000   999900000000           1298               0
# 9042   999900000000  1000200000000           1298               0
#
#        machine_id  alloc_collection_id  alloc_instance_index  collection_type  \
# 0     53771454236                    0                    -1                0
# ...
